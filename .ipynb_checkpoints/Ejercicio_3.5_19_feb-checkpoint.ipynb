# %%
import math

Eb=[]
Ea=[]

x=5
n=20

def factorial(a):
    r=1
    for it in range (1,a+1):
        r=r*it
    return (r)

def euler(n,x):
    resp=0
    Vaa=0
    signo=1;
    print ('{0:3} | {1:24} | {2:24} | {3:24} | {4:24}'.format('t',' e^x (metodo 1)' ,' e^x (metodo 2)' ,'Ea1 ','Eb1')) 
    for i in range (0,n):                  
        resp=resp+((x**(i))/factorial(i))*(signo)
        
        if signo==1:
            signo=-1
        else:
            signo=1
        
        Eb.append(math.fabs(math.exp(-5)-resp))
        Ea.append(math.fabs(((resp-Vaa)/resp)*100))         
        Vaa=resp
        
        print ('{0:3} | {1:24} | {2:24} | {3:24} | {4:24}'.format(i+1,resp,metodo2(i,x),Ea[i],Eb[i]))   
        #if Ea[i]<=Es[i]:            
           # break                                   

    return (resp)       


def metodo2(a,x):
    resp=0
    Vaa=0
    signo=1;
    
    for i in range (0,a+1):                  
        resp=resp+((x**(i))/factorial(i))              
        if resp>0:
            resp=1/resp
    return (resp) 
    
print (euler(n,x))
# Out:
# t   |  e^x (metodo 1)          |  e^x (metodo 2)          | Ea1                      | Eb1
#   1 |                      1.0 |                      1.0 |                    100.0 |       0.9932620530009145
#   2 |                     -4.0 |      0.16666666666666666 |                    125.0 |        4.006737946999086
#   3 |                      8.5 |      0.07894736842105264 |       147.05882352941177 |        8.493262053000915
#   4 |      -12.333333333333332 |      0.04781879194630873 |       168.91891891891893 |       12.340071280332417
#   5 |       13.708333333333336 |      0.03832961756131024 |       189.96960486322186 |       13.701595386334251
#   6 |      -12.333333333333332 |      0.03834356374524315 |       211.14864864864867 |       12.340071280332417
#   7 |        9.368055555555557 |      0.04599872616550225 |       231.65307635285393 |        9.361317608556472
# ...
